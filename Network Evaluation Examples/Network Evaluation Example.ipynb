# %%
from network_evaluation_tools import data_import_tools as dit
from network_evaluation_tools import network_evaluation_functions as nef
from network_evaluation_tools import network_propagation as prop
import pandas as pd
import numpy as np

# %%
# Load network (We choose a smaller network here for the example's sake)
network = dit.load_network_file('../Data/string_edge_list_common_names.tsv', verbose=True, delimiter='\t')
print(len(network.nodes))
# Out:
# Network File Loaded: ../Data/string_edge_list_common_names.tsv
# 19344

# %%
# Load gene sets for analysis
genesets = dit.load_node_sets('../Data/DisGeNET_genesets.txt')

# %%
# Calculate geneset sub-sample rate
genesets_p = nef.calculate_p(network, genesets)

# %%
# Determine optimal alpha for network (can also be done automatically by next step)
alpha = prop.calculate_alpha(network)
print(alpha)
# Out:
# 0.55

# %%
import networkx as nx
print(len(network.nodes))
subs = list(nx.connected_component_subgraphs(network))
print(subs)

# %%
# Calculate network kernel for propagation
kernel = nef.construct_prop_kernel(network, alpha=alpha, verbose=True)
# Out:
# Alpha: 0.55
# Network Propagation Complete: 317.83964490890503 seconds
# Propagated network kernel constructed
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_propagation.py:56: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   binary_matrix_filt = np.array(binary_matrix.T.ix[subgraph_nodes].fillna(0).T)
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   network_Fn = network_Fn.ix[network_Fn.columns]

# %%
print(kernel.index)
print(genesets)

# %%
# Calculate the AUPRC values for each gene set
AUPRC_values = nef.small_network_AUPRC_wrapper(kernel, genesets, genesets_p, n=30, cores=4, verbose=True)
# Out:
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# AUPRC Analysis for given node set (117 nodes in network) complete: 2.9 seconds.
# AUPRC Analysis for given node set (121 nodes in network) complete: 2.95 seconds.
# AUPRC Analysis for given node set (118 nodes in network) complete: 3.02 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 3.44 seconds.
# AUPRC Analysis for given node set (90 nodes in network) complete: 1.85 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (211 nodes in network) complete: 2.75 seconds.
# AUPRC Analysis for given node set (210 nodes in network) complete: 2.79 seconds.
# AUPRC Analysis for given node set (70 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (79 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (121 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (238 nodes in network) complete: 2.75 seconds.
# AUPRC Analysis for given node set (217 nodes in network) complete: 2.58 seconds.
# AUPRC Analysis for given node set (176 nodes in network) complete: 2.24 seconds.
# AUPRC Analysis for given node set (246 nodes in network) complete: 2.64 seconds.
# AUPRC Analysis for given node set (204 nodes in network) complete: 2.39 seconds.
# AUPRC Analysis for given node set (106 nodes in network) complete: 1.78 seconds.
# AUPRC Analysis for given node set (111 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (82 nodes in network) complete: 1.69 seconds.
# AUPRC Analysis for given node set (110 nodes in network) complete: 1.81 seconds.
# AUPRC Analysis for given node set (240 nodes in network) complete: 2.58 seconds.
# AUPRC Analysis for given node set (196 nodes in network) complete: 2.31 seconds.
# AUPRC Analysis for given node set (167 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (89 nodes in network) complete: 1.67 seconds.
# AUPRC Analysis for given node set (95 nodes in network) complete: 1.74 seconds.
# AUPRC Analysis for given node set (76 nodes in network) complete: 1.65 seconds.
# AUPRC Analysis for given node set (117 nodes in network) complete: 1.89 seconds.
# AUPRC Analysis for given node set (197 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (88 nodes in network) complete: 1.72 seconds.
# AUPRC Analysis for given node set (106 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (120 nodes in network) complete: 1.87 seconds.
# AUPRC Analysis for given node set (189 nodes in network) complete: 2.27 seconds.
# AUPRC Analysis for given node set (191 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (95 nodes in network) complete: 1.76 seconds.
# AUPRC Analysis for given node set (99 nodes in network) complete: 1.8 seconds.
# AUPRC Analysis for given node set (90 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set AUPRC Analysis for given node set(70 nodes in network) complete:  (118 nodes in network) complete:1.59  1.91seconds.
# seconds.
# AUPRC Analysis for given node set (102 nodes in network) complete: 1.77 seconds.
# AUPRC Analysis for given node set (44 nodes in network) complete: 1.36 seconds.
# AUPRC Analysis for given node set (90 nodes in network) complete: 1.74 seconds.
# AUPRC Analysis for given node set (148 nodes in network) complete: 2.06 seconds.
# AUPRC Analysis for given node set (141 nodes in network) complete: 1.99 seconds.
# AUPRC Analysis for given node set (114 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (196 nodes in network) complete: 2.28 seconds.
# AUPRC Analysis for given node set (274 nodes in network) complete: 2.71 seconds.
# AUPRC Analysis for given node set (89 nodes in network) complete: 1.65 seconds.
# AUPRC Analysis for given node set (114 nodes in network) complete: 1.8 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.92 seconds.
# AUPRC Analysis for given node set (195 nodes in network) complete: 2.29 seconds.
# AUPRC Analysis for given node set (181 nodes in network) complete: 2.21 seconds.
# AUPRC Analysis for given node set (246 nodes in network) complete: 2.59 seconds.
# AUPRC Analysis for given node set (72 nodes in network) complete: 1.56 seconds.
# AUPRC Analysis for given node set (275 nodes in network) complete: 2.75 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.04 seconds.
# AUPRC Analysis for given node set (213 nodes in network) complete: 2.47 seconds.
# AUPRC Analysis for given node set (111 nodes in network) complete: 1.83 seconds.
# AUPRC Analysis for given node set (253 nodes in network) complete: 2.64 seconds.
# AUPRC Analysis for given node set (196 nodes in network) complete: 2.31 seconds.
# AUPRC Analysis for given node set (149 nodes in network) complete: 2.12 seconds.
# AUPRC Analysis for given node set (160 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (149 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (174 nodes in network) complete: 2.24 seconds.
# AUPRC Analysis for given node set (252 nodes in network) complete: 2.62 seconds.
# AUPRC Analysis for given node set (96 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (86 nodes in network) complete: 1.61 seconds.
# AUPRC Analysis for given node set (193 nodes in network) complete: 2.27 seconds.
# AUPRC Analysis for given node set (138 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (215 nodes in network) complete: 2.46 seconds.
# AUPRC Analysis for given node set (201 nodes in network) complete: 2.36 seconds.
# AUPRC Analysis for given node set (282 nodes in network) complete: 2.79 seconds.
# AUPRC Analysis for given node set (79 nodes in network) complete: 1.63 seconds.
# AUPRC Analysis for given node set (156 nodes in network) complete: 2.08 seconds.
# AUPRC Analysis for given node set (176 nodes in network) complete: 2.21 seconds.
# AUPRC Analysis for given node set (276 nodes in network) complete: 2.73 seconds.
# AUPRC Analysis for given node set (151 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (197 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.78 seconds.
# AUPRC Analysis for given node set (202 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (263 nodes in network) complete: 2.69 seconds.
# AUPRC Analysis for given node set (215 nodes in network) complete: 2.54 seconds.
# AUPRC Analysis for given node set (142 nodes in network) complete: 2.1 seconds.
# AUPRC Analysis for given node set (132 nodes in network) complete: 2.02 seconds.
# AUPRC Analysis for given node set (246 nodes in network) complete: 2.74 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.91 seconds.
# AUPRC Analysis for given node set (134 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (100 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (263 nodes in network) complete: 2.73 seconds.
# AUPRC Analysis for given node set (131 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (72 nodes in network) complete: 1.57 seconds.
# AUPRC Analysis for given node set (247 nodes in network) complete: 2.64 seconds.
# AUPRC Analysis for given node set (163 nodes in network) complete: 2.14 seconds.
# AUPRC Analysis for given node set (173 nodes in network) complete: 2.19 seconds.
# AUPRC Analysis for given node set (150 nodes in network) complete: 2.04 seconds.
# AUPRC Analysis for given node set (92 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (91 nodes in network) complete: 1.69 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.78 seconds.
# AUPRC Analysis for given node set (217 nodes in network) complete: 2.44 seconds.
# AUPRC Analysis for given node set (189 nodes in network) complete: 2.25 seconds.
# AUPRC Analysis for given node set (140 nodes in network) complete: 1.96 seconds.
# AUPRC Analysis for given node set (151 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (76 nodes in network) complete: 1.57 seconds.
# AUPRC Analysis for given node set (176 nodes in network) complete: 2.18 seconds.
# AUPRC Analysis for given node set (113 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (155 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (135 nodes in network) complete: 1.95 seconds.
# AUPRC Analysis for given node set (113 nodes in network) complete: 1.81 seconds.
# AUPRC Analysis for given node set (145 nodes in network) complete: 2.02 seconds.
# AUPRC Analysis for given node set (194 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (150 nodes in network) complete: 2.09 seconds.
# AUPRC Analysis for given node set (255 nodes in network) complete: 2.67 seconds.
# AUPRC Analysis for given node set (136 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (153 nodes in network) complete: 2.08 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.02 seconds.
# AUPRC Analysis for given node set (197 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (108 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (271 nodes in network) complete: 2.69 seconds.
# AUPRC Analysis for given node set (220 nodes in network) complete: 2.46 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 2.22 seconds.
# AUPRC Analysis for given node set (214 nodes in network) complete: 2.49 seconds.
# AUPRC Analysis for given node set (206 nodes in network) complete: 2.47 seconds.
# AUPRC Analysis for given node set (260 nodes in network) complete: 2.66 seconds.
# AUPRC Analysis for given node set (227 nodes in network) complete: 2.48 seconds.
# AUPRC Analysis for given node set (130 nodes in network) complete: 1.95 seconds.
# AUPRC Analysis for given node set (113 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (127 nodes in network) complete: 1.93 seconds.
# AUPRC Analysis for given node set (124 nodes in network) complete: 1.86 seconds.
# AUPRC Analysis for given node set (106 nodes in network) complete: 1.77 seconds.
# AUPRC Analysis for given node set (213 nodes in network) complete: 2.44 seconds.
# AUPRC Analysis for given node set (156 nodes in network) complete: 2.1 seconds.
# AUPRC Analysis for given node set (155 nodes in network) complete: 2.06 seconds.
# AUPRC Analysis for given node set (93 nodes in network) complete: 1.66 seconds.
# AUPRC Analysis for given node set (162 nodes in network) complete: 2.13 seconds.
# AUPRC Analysis for given node set (196 nodes in network) complete: 2.33 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (185 nodes in network) complete: 2.31 seconds.
# AUPRC Analysis for given node set (132 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (163 nodes in network) complete: 2.17 seconds.
# AUPRC Analysis for given node set (100 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (98 nodes in network) complete: 1.72 seconds.
# AUPRC Analysis for given node set (177 nodes in network) complete: 2.19 seconds.
# AUPRC Analysis for given node set (264 nodes in network) complete: 2.68 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.83 seconds.
# AUPRC Analysis for given node set (112 nodes in network) complete: 1.81 seconds.
# AUPRC Analysis for given node set (201 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (205 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (128 nodes in network) complete: 1.91 seconds.
# AUPRC Analysis for given node set (255 nodes in network) complete: 2.62 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.93 seconds.
# AUPRC Analysis for given node set (95 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (80 nodes in network) complete: 1.63 seconds.
# AUPRC Analysis for given node set (221 nodes in network) complete: 2.48 seconds.
# AUPRC Analysis for given node set (238 nodes in network) complete: 2.57 seconds.
# AUPRC Analysis for given node set (239 nodes in network) complete: 2.54 seconds.
# AUPRC Analysis for given node set (60 nodes in network) complete: 1.47 seconds.
# AUPRC Analysis for given node set (179 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (144 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (124 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (230 nodes in network) complete: 2.46 seconds.
# AUPRC Analysis for given node set (167 nodes in network) complete: 2.11 AUPRC Analysis for given node setseconds.
# (171 nodes in network) complete: 2.16 seconds.
# AUPRC Analysis for given node set (89 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (115 nodes in network) complete: 1.81 seconds.
# AUPRC Analysis for given node set (108 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (75 nodes in network) complete: 1.58 seconds.
# AUPRC Analysis for given node set (207 nodes in network) complete: 2.39 seconds.
# AUPRC Analysis for given node set (171 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (152 nodes in network) complete: 2.04 seconds.
# AUPRC Analysis for given node set (87 nodes in network) complete: 1.67 seconds.
# AUPRC Analysis for given node set (161 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (271 nodes in network) complete: 2.67 seconds.
# AUPRC Analysis for given node set (156 nodes in network) complete: 2.07 seconds.
# AUPRC Analysis for given node set (153 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (164 nodes in network) complete: 2.13 seconds.
# AUPRC Analysis for given node set (223 nodes in network) complete: 2.48 seconds.
# AUPRC Analysis for given node set (178 nodes in network) complete: 2.19 seconds.
# AUPRC Analysis for given node set (195 nodes in network) complete: 2.26 seconds.
# AUPRC Analysis for given node set (118 nodes in network) complete: 1.82 AUPRC Analysis for given node set seconds.(137 nodes in network) complete:
#  1.95 seconds.
# AUPRC Analysis for given node set (272 nodes in network) complete: 2.68 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (121 nodes in network) complete: 1.85 seconds.
# AUPRC Analysis for given node set (142 nodes in network) complete: 1.95 seconds.
# AUPRC Analysis for given node set (139 nodes in network) complete: 1.96 seconds.
# AUPRC Analysis for given node set (226 nodes in network) complete: 2.45 seconds.
# AUPRC Analysis for given node set (86 nodes in network) complete: 1.66 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.92 seconds.
# AUPRC Analysis for given node set (209 nodes in network) complete: 2.41 seconds.
# AUPRC Analysis for given node set (272 nodes in network) complete: 2.67 seconds.
# AUPRC Analysis for given node set (200 nodes in network) complete: 2.33 seconds.
# AUPRC Analysis for given node set (244 nodes in network) complete: 2.53 seconds.
# AUPRC Analysis for given node set (101 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (77 nodes in network) complete: 1.57 seconds.
# AUPRC Analysis for given node set (70 nodes in network) complete: 1.55 seconds.
# AUPRC Analysis for given node set (83 nodes in network) complete: 1.6 seconds.
# AUPRC Analysis for given node set (176 nodes in network) complete: 2.18 seconds.
# AUPRC Analysis for given node set (94 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (65 nodes in network) complete: 1.5 seconds.
# AUPRC Analysis for given node set (198 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (95 nodes in network) complete: 1.66 seconds.
# AUPRC Analysis for given node set (66 nodes in network) complete: 1.47 seconds.
# AUPRC Analysis for given node set (96 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (202 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (111 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (177 nodes in network) complete: 2.22 seconds.
# AUPRC Analysis for given node set (245 nodes in network) complete: 2.65 seconds.
# AUPRC Analysis for given node set (238 nodes in network) complete: 2.64 seconds.
# AUPRC Analysis for given node set (91 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (222 nodes in network) complete: 2.49 seconds.
# AUPRC Analysis for given node set (184 nodes in network) complete: 2.22 seconds.
# AUPRC Analysis for given node set (171 nodes in network) complete: 2.18 seconds.
# AUPRC Analysis for given node set (107 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (97 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (266 nodes in network) complete: 2.62 seconds.
# AUPRC Analysis for given node set (189 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (69 nodes in network) complete: 1.51 seconds.
# AUPRC Analysis for given node setAUPRC Analysis for given node set (99 nodes in network) complete:  (154 nodes in network) complete: 1.722.03  seconds.seconds.
#
# AUPRC Analysis for given node set (228 nodes in network) complete: 2.45 seconds.
# AUPRC Analysis for given node set (84 nodes in network) complete: 1.62 seconds.
# AUPRC Analysis for given node set (105 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (162 nodes in network) complete: 2.08 seconds.
# AUPRC Analysis for given node set (149 nodes in network) complete: 2.01 seconds.
# AUPRC Analysis for given node set (234 nodes in network) complete: 2.49 seconds.
# AUPRC Analysis for given node set (74 nodes in network) complete: 1.61 seconds.
# AUPRC Analysis for given node set (71 nodes in network) complete: 1.6 seconds.
# AUPRC Analysis for given node set (170 nodes in network) complete: 2.16 seconds.
# AUPRC Analysis for given node set (115 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (203 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (155 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (162 nodes in network) complete: 2.1 seconds.
# AUPRC Analysis for given node set (234 nodes in network) complete: 2.47 seconds.
# AUPRC Analysis for given node set (119 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (163 nodes in network) complete: 2.1 seconds.
# AUPRC Analysis for given node set (201 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (108 nodes in network) complete: 1.78 seconds.
# AUPRC Analysis for given node set (81 nodes in network) complete: 1.6 seconds.
# AUPRC Analysis for given node set (110 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node setAUPRC Analysis for given node set  (204 nodes in network) complete:(213 nodes in network) complete:  2.332.41  seconds.seconds.
#
# AUPRC Analysis for given node set (143 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (101 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (80 nodes in network) complete: 1.58 seconds.
# AUPRC Analysis for given node set (173 nodes in network) complete: 2.14 seconds.
# AUPRC Analysis for given node set (226 nodes in network) complete: 2.48 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (114 nodes in network) complete: 1.86 seconds.
# AUPRC Analysis for given node set (197 nodes in network) complete: 2.29 seconds.
# AUPRC Analysis for given node set (109 nodes in network) complete: 1.86 seconds.
# AUPRC Analysis for given node set (91 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.77 seconds.
# AUPRC Analysis for given node set (188 nodes in network) complete: 2.23 seconds.
# AUPRC Analysis for given node set (114 nodes in network) complete: 1.8 seconds.
# AUPRC Analysis for given node set (201 nodes in network) complete: 2.31 seconds.
# AUPRC Analysis for given node set (96 nodes in network) complete: 1.68 seconds.
# AUPRC Analysis for given node set (57 nodes in network) complete: 1.44 seconds.
# AUPRC Analysis for given node set (127 nodes in network) complete: 1.87 seconds.
# AUPRC Analysis for given node set (102 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (241 nodes in network) complete: 2.55 seconds.
# AUPRC Analysis for given node set (154 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (123 nodes in network) complete: 1.87 seconds.
# AUPRC Analysis for given node set (71 nodes in network) complete: 1.56 seconds.
# AUPRC Analysis for given node set (159 nodes in network) complete: 2.09 seconds.
# AUPRC Analysis for given node set (151 nodes in network) complete: 2.01 seconds.
# AUPRC Analysis for given node set (128 nodes in network) complete: 1.89 seconds.
# AUPRC Analysis for given node set (137 nodes in network) complete: 1.93 seconds.
# AUPRC Analysis for given node set (145 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (156 nodes in network) complete: 2.08 seconds.
# AUPRC Analysis for given node set (148 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (195 nodes in network) complete: 2.29 seconds.
# AUPRC Analysis for given node set (222 nodes in network) complete: 2.47 seconds.
# AUPRC Analysis for given node set (153 nodes in network) complete: 2.01 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.76 seconds.
# AUPRC Analysis for given node set (99 nodes in network) complete: 1.72 seconds.
# AUPRC Analysis for given node set (132 nodes in network) complete: 1.93 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (151 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.81 seconds.
# AUPRC Analysis for given node set (189 nodes in network) complete: 2.25 seconds.
# AUPRC Analysis for given node set (140 nodes in network) complete: 1.96 seconds.
# AUPRC Analysis for given node set (236 nodes in network) complete: 2.51 seconds.
# AUPRC Analysis for given node set (137 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (122 nodes in network) complete: 1.89 seconds.
# AUPRC Analysis for given node set (136 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (241 nodes in network) complete: 2.57 seconds.
# AUPRC Analysis for given node set (133 nodes in network) complete: 1.95 seconds.
# AUPRC Analysis for given node set (274 nodes in network) complete: 2.68 seconds.
# AUPRC Analysis for given node set (133 nodes in network) complete: 1.91 seconds.
# AUPRC Analysis for given node set (111 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (96 nodes in network) complete: 1.7 seconds.
# AUPRC Analysis for given node set (136 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.94 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (168 nodes in network) complete: 2.14 seconds.
# AUPRC Analysis for given node set (102 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.9 seconds.
# AUPRC Analysis for given node set (181 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (173 nodes in network) complete: 2.16 seconds.
# AUPRC Analysis for given node set (226 nodes in network) complete: 2.47 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.76 seconds.
# AUPRC Analysis for given node set (115 nodes in network) complete: 1.8 seconds.
# AUPRC Analysis for given node set (166 nodes in network) complete: 2.11 seconds.
# AUPRC Analysis for given node set (94 nodes in network) complete: 1.69 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.8 seconds.
# AUPRC Analysis for given node set (121 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (93 nodes in network) complete: 1.7 seconds.
# AUPRC Analysis for given node set (188 nodes in network) complete: 2.22 seconds.
# AUPRC Analysis for given node set (253 nodes in network) complete: 2.59 seconds.
# AUPRC Analysis for given node set (205 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (128 nodes in network) complete: 1.89 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 1.9 seconds.
# AUPRC Analysis for given node set (139 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (239 nodes in network) complete: 2.53 seconds.
# AUPRC Analysis for given node set (98 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (169 nodes in network) complete: 2.14 seconds.
# AUPRC Analysis for given node set (153 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (175 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (264 nodes in network) complete: 2.69 seconds.
# AUPRC Analysis for given node set (196 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (274 nodes in network) complete: 2.76 seconds.
# AUPRC Analysis for given node set (192 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (200 nodes in network) complete: 2.34 seconds.
# AUPRC Analysis for given node set (171 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (84 nodes in network) complete: 1.6 seconds.
# AUPRC Analysis for given node set (123 nodes in network) complete: 1.86 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (266 nodes in network) complete: 2.67 seconds.
# AUPRC Analysis for given node set (241 nodes in network) complete: 2.65 seconds.
# AUPRC Analysis for given node set (240 nodes in network) complete: 2.62 seconds.
# AUPRC Analysis for given node set (199 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (128 nodes in network) complete: 1.92 seconds.
# AUPRC Analysis for given node set (202 nodes in network) complete: 2.38 seconds.
# AUPRC Analysis for given node set (137 nodes in network) complete: 2.09 seconds.
# AUPRC Analysis for given node set (102 nodes in network) complete: 1.89 seconds.
# AUPRC Analysis for given node set (84 nodes in network) complete: 1.73 seconds.
# AUPRC Analysis for given node set (267 nodes in network) complete: 2.82 seconds.
# AUPRC Analysis for given node set (94 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (239 nodes in network) complete: 2.61 seconds.
# AUPRC Analysis for given node set (64 nodes in network) complete: 1.62 seconds.
# AUPRC Analysis for given node set (159 nodes in network) complete: 2.21 seconds.
# AUPRC Analysis for given node set (114 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (102 nodes in network) complete: 1.85 seconds.
# AUPRC Analysis for given node set (191 nodes in network) complete: 2.42 seconds.
# AUPRC Analysis for given node set (125 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.85 seconds.
# AUPRC Analysis for given node set (90 nodes in network) complete: 1.74 seconds.
# AUPRC Analysis for given node set (187 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (232 nodes in network) complete: 2.56 seconds.
# AUPRC Analysis for given node set (110 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (93 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.9 seconds.
# AUPRC Analysis for given node set (130 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (116 nodes in network) complete: 1.98 seconds.
# AUPRC Analysis for given node set (95 nodes in network) complete: 1.86 seconds.
# AUPRC Analysis for given node set (74 nodes in network) complete: 1.7 seconds.
# AUPRC Analysis for given node set (268 nodes in network) complete: 2.78 seconds.
# AUPRC Analysis for given node set (148 nodes in network) complete: 2.06 seconds.
# AUPRC Analysis for given node set (208 nodes in network) complete: 2.48 seconds.
# AUPRC Analysis for given node set (206 nodes in network) complete: 2.45 seconds.
# AUPRC Analysis for given node set (141 nodes in network) complete: 2.04 seconds.
# AUPRC Analysis for given node set (126 nodes in network) complete: 1.95 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.06 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.06 seconds.
# AUPRC Analysis for given node set (84 nodes in network) complete: 1.69 seconds.
# AUPRC Analysis for given node set (147 nodes in network) complete: 2.07 seconds.
# AUPRC Analysis for given node set (189 nodes in network) complete: 2.29 seconds.
# AUPRC Analysis for given node set (163 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (100 nodes in network) complete: 1.75 seconds.
# AUPRC Analysis for given node set (191 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (88 nodes in network) complete: 1.72 seconds.
# AUPRC Analysis for given node set (245 nodes in network) complete: 2.63 seconds.
# AUPRC Analysis for given node set (181 nodes in network) complete: 2.45 seconds.
# AUPRC Analysis for given node set (93 nodes in network) complete: 1.99 seconds.
# AUPRC Analysis for given node set (173 nodes in network) complete: 2.46 seconds.
# AUPRC Analysis for given node set (156 nodes in network) complete: 2.41 seconds.
# AUPRC Analysis for given node set (124 nodes in network) complete: 2.26 seconds.
# AUPRC Analysis for given node set (127 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (193 nodes in network) complete: 2.73 seconds.
# AUPRC Analysis for given node set (183 nodes in network) complete: 2.67 seconds.
# AUPRC Analysis for given node set (90 nodes in network) complete: 2.01 seconds.
# AUPRC Analysis for given node set (235 nodes in network) complete: 2.95 seconds.
# AUPRC Analysis for given node set (160 nodes in network) complete: 2.43 seconds.
# AUPRC Analysis for given node set (157 nodes in network) complete: 2.36 seconds.
# AUPRC Analysis for given node set (264 nodes in network) complete: 3.04 seconds.
# AUPRC Analysis for given node set (113 nodes in network) complete: 1.96 seconds.
# AUPRC Analysis for given node set (129 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (105 nodes in network) complete: 1.87 seconds.
# AUPRC Analysis for given node set (146 nodes in network) complete: 2.09 seconds.
# AUPRC Analysis for given node set (179 nodes in network) complete: 2.28 seconds.
# AUPRC Analysis for given node set (120 nodes in network) complete: 1.96 seconds.
# AUPRC Analysis for given node set (157 nodes in network) complete: 2.18 seconds.
# AUPRC Analysis for given node set (176 nodes in network) complete: 2.32 seconds.
# AUPRC Analysis for given node set (85 nodes in network) complete: 1.76 seconds.
# AUPRC Analysis for given node set (130 nodes in network) complete: 2.05 seconds.
# AUPRC Analysis for given node set (93 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (216 nodes in network) complete: 2.55 seconds.
# AUPRC Analysis for given node set (125 nodes in network) complete: 1.93 seconds.
# AUPRC Analysis for given node set (268 nodes in network) complete: 2.72 seconds.
# AUPRC Analysis for given node set (73 nodes in network) complete: 1.59 seconds.
# AUPRC Analysis for given node set (179 nodes in network) complete: 2.25 seconds.
# AUPRC Analysis for given node set (87 nodes in network) complete: 1.82 seconds.
# AUPRC Analysis for given node set (163 nodes in network) complete: 2.3 seconds.
# AUPRC Analysis for given node set (200 nodes in network) complete: 2.53 seconds.
# AUPRC Analysis for given node set (124 nodes in network) complete: 2.03 seconds.
# AUPRC Analysis for given node set (127 nodes in network) complete: 1.99 seconds.
# AUPRC Analysis for given node set (130 nodes in network) complete: 1.94 seconds.
# AUPRC Analysis for given node set (136 nodes in network) complete: 1.97 seconds.
# AUPRC Analysis for given node set (194 nodes in network) complete: 2.29 seconds.
# AUPRC Analysis for given node set (97 nodes in network) complete: 1.76 seconds.
# AUPRC Analysis for given node set (236 nodes in network) complete: 2.55 seconds.
# AUPRC Analysis for given node set (230 nodes in network) complete: 2.53 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 2.26 seconds.
# AUPRC Analysis for given node set (204 nodes in network) complete: 2.36 seconds.
# AUPRC Analysis for given node set (96 nodes in network) complete: 1.72 seconds.
# AUPRC Analysis for given node set (83 nodes in network) complete: 1.64 seconds.
# AUPRC Analysis for given node set (145 nodes in network) complete: 2.0 seconds.
# AUPRC Analysis for given node set (188 nodes in network) complete: 2.25 seconds.
# AUPRC Analysis for given node set (72 nodes in network) complete: 1.63 seconds.
# AUPRC Analysis for given node set (166 nodes in network) complete: 2.24 seconds.
# AUPRC Analysis for given node set (160 nodes in network) complete: 2.2 seconds.
# AUPRC Analysis for given node set (222 nodes in network) complete: 2.58 seconds.
# AUPRC Analysis for given node set (94 nodes in network) complete: 1.79 seconds.
# AUPRC Analysis for given node set (262 nodes in network) complete: 2.8 seconds.
# AUPRC Analysis for given node set (144 nodes in network) complete: 2.14 seconds.
# AUPRC Analysis for given node set (105 nodes in network) complete: 1.9 seconds.
# AUPRC Analysis for given node set (284 nodes in network) complete: 2.96 seconds.
# AUPRC Analysis for given node set (144 nodes in network) complete: 2.15 seconds.
# AUPRC Analysis for given node set (180 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (165 nodes in network) complete: 2.26 seconds.
# AUPRC Analysis for given node set (144 nodes in network) complete: 2.12 seconds.
# AUPRC Analysis for given node set (177 nodes in network) complete: 2.37 seconds.
# AUPRC Analysis for given node set (184 nodes in network) complete: 2.35 seconds.
# AUPRC Analysis for given node set (134 nodes in network) complete: 2.01 seconds.
# AUPRC Analysis for given node set (104 nodes in network) complete: 1.85 seconds.
# AUPRC Analysis for given node set (92 nodes in network) complete: 1.84 seconds.
# AUPRC Analysis for given node set (240 nodes in network) complete: 2.7 seconds.
# AUPRC Analysis for given node set (92 nodes in network) complete: 1.69 seconds.
# AUPRC Analysis for given node set (175 nodes in network) complete: 2.17 seconds.
# AUPRC Analysis for given node set (103 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (172 nodes in network) complete: 2.04 seconds.
# AUPRC Analysis for given node set (111 nodes in network) complete: 1.71 seconds.
# AUPRC Analysis for given node set (240 nodes in network) complete: 2.4 seconds.
# AUPRC Analysis for given node set (121 nodes in network) complete: 1.7 seconds.
# AUPRC Analysis for given node set (241 nodes in network) complete: 2.29 seconds.

# %% [markdown]
# **Note about the above cell:** There are a several options for this particular step depending on the computational resources available and network size. If the network is sufficiently small (<250k edges), it is recommended to use the 'small_network_AUPRC_wrapper' function as it can be much faster, especially when run in parallel (at least 8G per core is recommended). If you would like to parallelize the AUPRC calculation with a larger network (between 250K and 2.5M edges), at least 16G per core is recommended, 32G per core if the network contains more than 2.5M edges. For larger networks, it is recommended to use the 'large_network_AUPRC_wrapper', which may be a slightly slower function, but more equipped to handle the larger memory footprint(required. To change the parllelization status of the function, change the 'cores' option to the number of threads you would like to utilize.)

# %%
# Construct null networks and calculate the AUPRC of the gene sets of the null networks
# We can use the AUPRC wrapper function for this
null_AUPRCs = []
for i in range(10):
    shuffNet = nef.shuffle_network(network, max_tries_n=10, verbose=True)
    shuffNet_kernel = nef.construct_prop_kernel(shuffNet, alpha=alpha, verbose=False)
    shuffNet_AUPRCs = nef.small_network_AUPRC_wrapper(shuffNet_kernel, genesets, genesets_p, n=30, cores=4, verbose=False)
    null_AUPRCs.append(shuffNet_AUPRCs)
    print('shuffNet', repr(i+1), 'AUPRCs calculated')
# Out:
# Network shuffled: 755.9287929534912 seconds. Edge similarity: 0.19687618840196253
# shuffNet 1 AUPRCs calculated
# Network shuffled: 773.5425930023193 seconds. Edge similarity: 0.19672764613249868
# shuffNet 2 AUPRCs calculated
# Network shuffled: 753.2581508159637 seconds. Edge similarity: 0.19681765628203635
# shuffNet 3 AUPRCs calculated
# Network shuffled: 741.5315568447113 seconds. Edge similarity: 0.1969445893095507
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_propagation.py:56: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   binary_matrix_filt = np.array(binary_matrix.T.ix[subgraph_nodes].fillna(0).T)
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   network_Fn = network_Fn.ix[network_Fn.columns]
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_propagation.py:56: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   binary_matrix_filt = np.array(binary_matrix.T.ix[subgraph_nodes].fillna(0).T)
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   network_Fn = network_Fn.ix[network_Fn.columns]
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_propagation.py:56: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   binary_matrix_filt = np.array(binary_matrix.T.ix[subgraph_nodes].fillna(0).T)
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   network_Fn = network_Fn.ix[network_Fn.columns]
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_propagation.py:56: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   binary_matrix_filt = np.array(binary_matrix.T.ix[subgraph_nodes].fillna(0).T)
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   network_Fn = network_Fn.ix[network_Fn.columns]
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:82: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:84: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   y_actual.ix[intersect_non_sample]+=1															# which nodes in sorted list are in intersect_non_sample
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# /Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py:91: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-23:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py", line 82, in calculate_small_network_AUPRC
#     bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 3164, in sort_values
#     argsorted = _try_kind_sort(arr[good])
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py", line 91, in calculate_small_network_AUPRC
#     precision.append(TP/float(y_actual.ix[:node].shape[0]))										 	# Calculate precision ( TP / TP+FP ) and add point to curve
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 3150, in _try_kind_sort
#     return arr.argsort(kind=kind)
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 148, in __getitem__
#     return self._getitem_axis(key, axis=axis)
#   File "/Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py", line 82, in calculate_small_network_AUPRC
#     bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 1014, in _getitem_axis
#     return self._get_slice_axis(key, axis=axis)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 3191, in sort_values
#     result = self._constructor(arr[sortedIdx], index=self.index[sortedIdx])
# Traceback (most recent call last):
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 1308, in _get_slice_axis
#     return self._slice(indexer, axis=axis, kind="iloc")
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 313, in __init__
#     data = SingleBlockManager(data, index, fastpath=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 166, in _slice
#     return self.obj._slice(obj, axis=axis, kind=kind)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1516, in __init__
#     block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 1063, in _slice
#     return self._get_values(slobj)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/internals/blocks.py", line 3249, in make_block
#     if isinstance(dtype, PandasDtype):
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 1180, in _get_values
#     self._data.get_slice(indexer), fastpath=True
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/series.py", line 317, in __init__
#     self.name = name
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/michael/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py", line 82, in calculate_small_network_AUPRC
#     bg_sample_sum = kernel.ix[sample][bg_non_sample].sum().sort_values(ascending=False)				# summed prop value for all nodes in background
# KeyboardInterrupt
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 148, in __getitem__
#     return self._getitem_axis(key, axis=axis)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 1022, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/indexing.py", line 1135, in _getitem_iterable
#     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/generic.py", line 4577, in _reindex_with_indexers
#     copy=copy,
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1267, in reindex_indexer
#     for blk in self.blocks
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1267, in <listcomp>
#     for blk in self.blocks
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/internals/blocks.py", line 1314, in take_nd
#     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#   File "/Users/michael/PycharmProjects/HW1/venv2/lib/python3.7/site-packages/pandas/core/algorithms.py", line 1721, in take_nd
#     func(arr, indexer, out, fill_value)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-23c341bc9715> in <module>
#       5     shuffNet = nef.shuffle_network(network, max_tries_n=10, verbose=True)
#       6     shuffNet_kernel = nef.construct_prop_kernel(shuffNet, alpha=alpha, verbose=False)
# ----> 7     shuffNet_AUPRCs = nef.small_network_AUPRC_wrapper(shuffNet_kernel, genesets, genesets_p, n=30, cores=4, verbose=False)
#       8     null_AUPRCs.append(shuffNet_AUPRCs)
#       9     print('shuffNet', repr(i+1), 'AUPRCs calculated')
#
# ~/PycharmProjects/Network_Evaluation_Tools/network_evaluation_tools/network_evaluation_functions.py in small_network_AUPRC_wrapper(net_kernel, genesets, genesets_p, n, cores, bg, verbose)
#     134                 pool = Pool(cores, global_var_initializer, [net_kernel])
#     135                 # Run the AUPRC analysis for each geneset
# --> 136                 AUPRC_results = pool.map(calculate_small_network_AUPRC, AUPRC_Analysis_params)
#     137                 # Close worker pool
#     138                 pool.close()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# **Note about the above cell:** We use a small number to calculate the null AUPRC values, but a larger number of shuffled networks may give a better representation of the true null AUPRC value.  smaller number of networks here for this example, but larger numbers can be used, especially if the resulting distribution of null AUPRCs has a high variance relative to the actual AUPRC values, but we have found that the variance remains relatively small even with a small number of shuffled networks.

# %%
# Construct table of null AUPRCs
null_AUPRCs_table = pd.concat(null_AUPRCs, axis=1)
null_AUPRCs_table.columns = ['shuffNet'+repr(i+1) for i in range(len(null_AUPRCs))]

# %%
# Calculate performance metric of gene sets
network_performance = nef.calculate_network_performance_score(AUPRC_values, null_AUPRCs_table, verbose=True)
network_performance.name = 'Test Network'

# %%
# Calculate network performance gain over median null AUPRC
network_perf_gain = nef.calculate_network_performance_gain(AUPRC_values, null_AUPRCs_table, verbose=True)
network_perf_gain.name = 'Test Network'

# %%
# Rank network on average performance across gene sets vs performance on same gene sets in previous network set
all_network_performance = pd.read_csv('~/Data/Network_Performance.csv', index_col=0)
all_network_performance_filt = pd.concat([network_performance, all_network_performance.ix[network_performance.index]], axis=1)
network_performance_rank_table = all_network_performance_filt.rank(axis=1, ascending=False)
network_performance_rankings = network_performance_rank_table['Test Network']

# %%
# Rank network on average performance gain across gene sets vs performance gain on same gene sets in previous network set
all_network_perf_gain = pd.read_csv('~/Data/Network_Performance_Gain.csv', index_col=0)
all_network_perf_gain_filt = pd.concat([network_perf_gain, all_network_perf_gain.ix[network_perf_gain.index]], axis=1)
network_perf_gain_rank_table = all_network_performance_filt.rank(axis=1, ascending=False)
network_perf_gain_rankings = network_perf_gain_rank_table['Test Network']

# %%
# Network Performance
network_performance_metric_ranks = pd.concat([network_performance, network_performance_rankings, network_perf_gain, network_perf_gain_rankings], axis=1)
network_performance_metric_ranks.columns = ['Network Performance', 'Network Performance Rank', 'Network Performance Gain', 'Network Performance Gain Rank']
network_performance_metric_ranks.sort_values(by=['Network Performance Rank', 'Network Performance', 'Network Performance Gain Rank', 'Network Performance Gain'],
                                             ascending=[True, False, True, False])

# %%
# Construct network summary table
network_summary = {}
network_summary['Nodes'] = int(len(network.nodes()))
network_summary['Edges'] = int(len(network.edges()))
network_summary['Avg Node Degree'] = np.mean(network.degree().values())
network_summary['Edge Density'] = 2*network_summary['Edges'] / float((network_summary['Nodes']*(network_summary['Nodes']-1)))
network_summary['Avg Network Performance Rank'] = network_performance_rankings.mean()
network_summary['Avg Network Performance Rank, Rank'] = int(network_performance_rank_table.mean().rank().ix['Test Network'])
network_summary['Avg Network Performance Gain Rank'] = network_perf_gain_rankings.mean()
network_summary['Avg Network Performance Gain Rank, Rank'] = int(network_perf_gain_rank_table.mean().rank().ix['Test Network'])
for item in ['Nodes', 'Edges' ,'Avg Node Degree', 'Edge Density', 'Avg Network Performance Rank', 'Avg Network Performance Rank, Rank',
             'Avg Network Performance Gain Rank', 'Avg Network Performance Gain Rank, Rank']:
    print(item+':\t'+repr(network_summary[item]))
